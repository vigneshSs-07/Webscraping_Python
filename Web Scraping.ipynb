# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'thttps://www.goibibo.com/hotels/hotels-in-shimla-ct/'

# %% [raw]
# headers = {
#     'User-Agent' : " Mozilla/5.0 (X11 ; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) chrome/77.0.3865.90 Safari/537.36 "
# }
#
# , headers = headers

# %%
response = requests.request("GET", url)

# %%
data =  BeautifulSoup(response.text, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script>
#           var starttime = new Date();
#         </script>
# <title data-react-helmet="true">Hotels in Shimla, 444 Shimla Hotels from ₹300 + upto 30% off</title>
# ...

# %%
cards_data = data.findall('div', attrs = {'class', 'width100 f1htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-408359b9e04b> in <module>
# ----> 1 cards_data = data.findall('div', attrs = {'class', 'width100 f1htlListSeo hotel-tile-srp-container hotel-tile-srp-container-template new-htl-design-tile-main-block'})
#
# TypeError: 'NoneType' object is not callable

# %%
cards_data = data.findall('div', attrs = {'class', 'HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 dFVxSO'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-a5a49abb467b> in <module>
# ----> 1 cards_data = data.findall('div', attrs = {'class', 'HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 dFVxSO'})
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# # Scrape Images in Python

# %%
images = data.find_all('img',src = True)

# %%
print('Number os images :', len(images))
# Out:
# Number os images : 72

# %%
for image in images:
    print(image)
# Out:
# <img src="https://goibibo.ibcdn.com/styleguide/images/goLogo.png"/>
# <img alt="irctc train logo" class="marginT5 marginB5" height="25px" src="https://goibibo.ibcdn.com/styleguide/images/train_logo.png" width="24px"/>
# <img alt="" height="41px" src="https://gos3.ibcdn.com/gotripe-new2x-1600243849.png" width="84px"/>
# <img class="fl" height="23px" src="https://goibibo.ibcdn.com/styleguide/images/goCash-header.png" width="23px"/>
# <img alt="" class="HotelCardImageGallerystyles__ImageStyle-r3dzqu-1 dFVxSO" data-testid="" itemprop="" src="..."/>
# <img alt="" class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 kvUkTQ" data-testid="" itemprop="" src="..."/>
# <img alt="" class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 kvUkTQ" data-testid="" itemprop="" src="..."/>
# <img alt="" class="HotelCardImageGallerystyles__MiniImageStyle-r3dzqu-2 kvUkTQ" data-testid="" itemprop="" src="..."/>
# ...

# %%
image_src = [x['src'] for x in images]

# %%
image_src = [x for x in image_src if x.endswith('.jpg')]

# %%
for image in images_src:
    print(image)

# %%
image_count = 1
for image in image_src:
    with open('image_'+ str(image_count)+'.jpg','wb') as f:
        res = requests.get(image)
        f.write(res.content)
    image_count =+ 1
